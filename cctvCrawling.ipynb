# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import shutil
import urllib.request
import time
import os
import timeit

start_time = timeit.default_timer() # 시작 시간 체크

options = webdriver.ChromeOptions()
options.add_argument('headless')
# driver = webdriver.Chrome('/Users/sanengr/Downloads/chromedriver',options=options)
driver = webdriver.Chrome('/Users/sanengr/Downloads/chromedriver')

driver.get('http://www.roadplus.co.kr/main/main.do#none')
info_drive = driver.find_element_by_xpath('//*[@title="노선별교통정보"]')
info_drive.click()

time.sleep(1)

# for link in soup.find_all('a'):
#     print(link.get('onclick'))
    
linkList = [
'\"fnTrafficDetailList(\'0010\',\'E\',\'1\',\'경부선\');\"',
'\"fnTrafficDetailList(\'0150\',\'E\',\'1\',\'서해안선\');\"',
'\"fnTrafficDetailList(\'0352\',\'E\',\'1\',\'중부선\');\"',
'\"fnTrafficDetailList(\'0500\',\'E\',\'1\',\'영동선\');\"',
'\"fnTrafficDetailList(\'1000\',\'E\',\'1\',\'수도권제1순환선\');\"',
'\"fnTrafficDetailList(\'1200\',\'E\',\'1\',\'경인선\');\"',
'\"fnTrafficDetailList(\'0140\',\'E\',\'1\',\'고창담양선\');\"',
'\"fnTrafficDetailList(\'0120\',\'E\',\'1\',\'광주대구선\');\"',
'\"fnTrafficDetailList(\'0520\',\'E\',\'1\',\'광주원주선\');\"',
'\"fnTrafficDetailList(\'0290\',\'E\',\'1\',\'구리포천선\');\"',
'\"fnTrafficDetailList(\'4002\',\'E\',\'1\',\'구리포천지선\');\"',
'\"fnTrafficDetailList(\'1020\',\'E\',\'1\',\'남해1지선\');\"',
'\"fnTrafficDetailList(\'1040\',\'E\',\'1\',\'남해2지선\');\"',
'\"fnTrafficDetailList(\'0100\',\'E\',\'1\',\'남해선(순천-부산)\');\"',
'\"fnTrafficDetailList(\'0101\',\'E\',\'1\',\'남해선(영암-순천)\');\"',
'\"fnTrafficDetailList(\'0252\',\'E\',\'1\',\'논산천안선\');\"',
'\"fnTrafficDetailList(\'0301\',\'E\',\'1\',\'당진대전선\');\"',
'\"fnTrafficDetailList(\'0552\',\'E\',\'1\',\'대구부산선\');\"',
'\"fnTrafficDetailList(\'0200\',\'E\',\'1\',\'대구포항선\');\"',
'\"fnTrafficDetailList(\'3000\',\'E\',\'1\',\'대전남부선\');\"',
'\"fnTrafficDetailList(\'0652\',\'E\',\'1\',\'동해선(부산-포항)\');\"',
'\"fnTrafficDetailList(\'0650\',\'E\',\'1\',\'동해선(삼척-속초)\');\"',
'\"fnTrafficDetailList(\'0121\',\'E\',\'1\',\'무안광주선\');\"',
'\"fnTrafficDetailList(\'4000\',\'E\',\'1\',\'봉담동탄선\');\"',
'\"fnTrafficDetailList(\'0105\',\'E\',\'1\',\'부산신항선\');\"',
'\"fnTrafficDetailList(\'6000\',\'E\',\'1\',\'부산외곽선\');\"',
'\"fnTrafficDetailList(\'0651\',\'E\',\'1\',\'부산울산선\');\"',
'\"fnTrafficDetailList(\'3010\',\'E\',\'1\',\'상주영천선\');\"',
'\"fnTrafficDetailList(\'0172\',\'E\',\'1\',\'서울문산선\');\"',
'\"fnTrafficDetailList(\'0173\',\'E\',\'1\',\'서울문산지선\');\"',
'\"fnTrafficDetailList(\'0600\',\'E\',\'1\',\'서울양양선\');\"',
'\"fnTrafficDetailList(\'1510\',\'E\',\'1\',\'서천공주선\');\"',
'\"fnTrafficDetailList(\'0170\',\'E\',\'2\',\'수원광명선\');\"',
'\"fnTrafficDetailList(\'0270\',\'E\',\'1\',\'순천완주선\');\"',
'\"fnTrafficDetailList(\'0170\',\'E\',\'3\',\'오산화성선\');\"',
'\"fnTrafficDetailList(\'0320\',\'E\',\'1\',\'옥산오창선\');\"',
'\"fnTrafficDetailList(\'1710\',\'E\',\'1\',\'용인서울선\');\"',
'\"fnTrafficDetailList(\'0160\',\'E\',\'1\',\'울산선\');\"',
'\"fnTrafficDetailList(\'0201\',\'E\',\'1\',\'익산장수선\');\"',
'\"fnTrafficDetailList(\'1300\',\'E\',\'1\',\'인천공항선\');\"',
'\"fnTrafficDetailList(\'4001\',\'E\',\'1\',\'인천김포선\');\"',
'\"fnTrafficDetailList(\'1102\',\'E\',\'1\',\'인천대교선\');\"',
'\"fnTrafficDetailList(\'1100\',\'E\',\'1\',\'제2경인선\');\"',
'\"fnTrafficDetailList(\'0370\',\'E\',\'1\',\'제2중부선\');\"',
'\"fnTrafficDetailList(\'3300\',\'E\',\'1\',\'제3경인선\');\"',
'\"fnTrafficDetailList(\'0450\',\'E\',\'1\',\'중부내륙선\');\"',
'\"fnTrafficDetailList(\'4510\',\'E\',\'1\',\'중부내륙지선\');\"',
'\"fnTrafficDetailList(\'0550\',\'E\',\'2\',\'중앙선\');\"',
'\"fnTrafficDetailList(\'0550\',\'E\',\'1\',\'중앙선(삼락-대동)\');\"',
'\"fnTrafficDetailList(\'5510\',\'E\',\'1\',\'중앙선지선\');\"',
'\"fnTrafficDetailList(\'0300\',\'E\',\'1\',\'청주영덕선\');\"',
'\"fnTrafficDetailList(\'0351\',\'E\',\'1\',\'통영대전선\');\"',
'\"fnTrafficDetailList(\'0153\',\'E\',\'1\',\'평택시흥선\');\"',
'\"fnTrafficDetailList(\'0400\',\'E\',\'1\',\'평택제천선\');\"',
'\"fnTrafficDetailList(\'0170\',\'E\',\'1\',\'평택화성선\');\"',
'\"fnTrafficDetailList(\'0251\',\'E\',\'1\',\'호남선\');\"',
'\"fnTrafficDetailList(\'2510\',\'E\',\'1\',\'호남지선\');\"'
]

if os.path.exists('./cctvImg'):
    shutil.rmtree('./cctvImg')
os.makedirs('./cctvImg')

try:
    for cLink in linkList:
        if not os.path.exists('./cctvImg'):
            os.makedirs('./cctvImg/' + cLink[37:-4])
            
        fPath1 = './cctvImg/' + cLink[37:-4] + '/1'            
        fPath2 = './cctvImg/' + cLink[37:-4] + '/2'        

        if not os.path.exists('./cctvImg/' + cLink[37:-4] + '/1'):
            os.makedirs(fPath1)
        if not os.path.exists('./cctvImg/' + cLink[37:-4] + '/2'):            
            os.makedirs(fPath2)

        driver.find_element_by_xpath('//*[@onclick='+cLink+']').click()
        time.sleep(2)

        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")    
        img = soup.find_all(class_='thumb_wrap')
        
        if len(os.listdir(fPath1)) == 0:
            for i in enumerate(img):
                cctvNM = i[1].get_text()
                try:
                    imgUrl = i[1].find_all('img')[0]['src']
                    with urllib.request.urlopen(imgUrl) as f:
                        with open(fPath1 + '/' + cctvNM +'.jpg','wb') as h:
                            img_n = f.read()
                            h.write(img_n)
                except Exception as e:
                    print(e)
                    continue


        driver.find_element_by_xpath('//*[@id="edpntDrnm"]').click()
        time.sleep(2)

        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")    
        img = soup.find_all(class_='thumb_wrap')  

        if len(os.listdir(fPath2)) == 0:        
            for i in enumerate(img):
                cctvNM = i[1].get_text()
                try:
                    imgUrl = i[1].find_all('img')[0]['src']
                    with urllib.request.urlopen(imgUrl) as f:
                        with open(fPath2 + '/' + cctvNM +'.jpg','wb') as h:
                            img_n = f.read()
                            h.write(img_n)
                except Exception as e:
                    print(e)
                    continue

        info_drive.click()
        time.sleep(2)

except Exception as e:
    print(e)
    driver.quit()

print('정상종료')
driver.quit()

a = os.listdir('./cctvImg')
nm = []

for i in a:
    if i == '.DS_Store':
        os.remove('./cctvImg/' + i)        
        
    try:
        for j in os.listdir('./cctvImg/'+ i + '/1'):
            if j == '.DS_Store':
                print('j1',i,j)                
                os.remove('./cctvImg/' + i + '/' + j)
            nm.append(j[:-4].strip())            

        for j in os.listdir('./cctvImg/'+ i + '/2'):
            if j == '.DS_Store':
                print('j2',i,j)                
                os.remove('./cctvImg/' + i + '/' + j)
            nm.append(j[:-4].strip())            
    except Exception as e:
        print('e',e)

terminate_time = timeit.default_timer() # 종료 시간 체크  
 
print("%f초 걸렸습니다." % (terminate_time - start_time))
# Out:
# 6404

# %%
a = os.listdir('./cctvImg')
nm = []

for i in a:
    try:
        for j in os.listdir('./cctvImg/'+ i + '/1'):
            if j == '.DS_Store':
                print('j1',i,j)                
                os.remove('./cctvImg/' + i + '/' + j)
            nm.append(j[:-4].strip())            

        for j in os.listdir('./cctvImg/'+ i + '/2'):
            if j == '.DS_Store':
                print('j2',i,j)                
                os.remove('./cctvImg/' + i + '/' + j)
            nm.append(j[:-4].strip())            
    except Exception as e:
        print('e',e)

print(nm)
print(len(nm))
# Out:
# j1 경부선 .DS_Store
# e [Errno 2] No such file or directory: './cctvImg/경부선/.DS_Store'
# ['상곡교', '단밀2터널', '문의교', '파천1터널(청주외부1)', '문동1', '길안3터널(영덕외부2)', '영덕', '지품6터널(영덕외부)', '북의성', '달산2터널(영덕외부)', '동안동', '내서1터널(상주)', '회인쉼터(청주)', '파천3터널(영덕외부1)', '회인', '현하천1교', '지품9터널(청주외부)', '갈평육교', '[청원]문의1터널(청원2)', '미천교', '수리티터널(청주)-외부', '진보터널(청주외부)', '묵계1교', '상주휴게소', '단촌철교', '지품3터널(청주외부)', '수리티교', '지품6터널(청주외부)', '단밀2터널(청주외부)', '영덕터널(청주외부)', '안평1터널(청주외부1)', '영덕터널(청주외부2)', '파천1터널(청주외부2)', '지품2터널(영덕외부)', '안평2터널(영덕외부)', '갈평교', '나각산터널(영덕외부)', '문의휴게소1', '구병산교', '길안3터널(영덕외부1)', '청송', '낙동분기점_청주상주', '화서', '수한터널', '지천4교', '길안4터널(청주외부)', '운평1교', '지품2터널(청주외부)', '길안1터널(청주외부)', '성암교', '파천3터널(영덕외부2)', '서변1교', '문의2터널(청주)-외부', '상주쉼터(상주)', '지품7터널(청주외부)', '서원4교', '지품8터널(청주외부)', '척산1', '평각3교', '안평1터널(청주외부2)', '장림천교', '척산', '지품2교', '탄부터널', '사일산터널(청주외부1)', '지품8터널(영덕외부)', '단촌2터널', '지품7터널(영덕외부)', '안평2터널(영덕외부2)', '상주분기점', '내서3터널(청주)-외부', '삼가천교', '속리산', '단촌4터널(청주외부2)', '화서휴게소', '안사2터널(청주외부)', '양곡교', '지품10터널(영덕외부)', '지사교', '달천1교', '회인터널(상주)-외부', '서원1교', '문동', '[청원]내서1터널(청원)', '파천2터널(청주외부)', '안동분기점', '지품1터널(청주외부)', '평온교', '보은', '내서1교', '옥산터널', '길안1터널', '길안천교', '안평2터널(청주외부)', '서원3교', '사일산터널(영덕외부)', '동상주', '가덕', '단촌1터널', '속리산휴게소', '신촌', '달산2터널(영덕외부1)', '단촌4터널(청주외부1)', '피반령터널(청주)-외부', '의성SA', '단밀4터널(청주외부)', '단밀1터널', '파천3터널(청주외부)', '금굴교', '문의1터널(상주)-외부', '지품3터널(영덕외부)', '상주쉼터(청주)', '탄부', '복곡2교', '서재교', '문의휴게소', '서의성', '성리교', '문의', '지품10터널(청주외부)', '단촌3터널(영덕외부)', '내서1터널', '안사1터널(영덕외부)', '금산리', '동청송영양', '청주분기점', '안평3터널(청주외부)', '점곡SA(영덕)', '남상주', '단밀2터널', '문의교', '파천1터널(청주외부1)', '화서', '상곡교', '문동1', '길안3터널(영덕외부2)', '영덕', '지품6터널(영덕외부)', '달산2터널(영덕외부)', '금굴교', '내서1터널(상주)', '회인쉼터(청주)', '영덕터널(청주외부2)', '파천3터널(영덕외부1)', '현하천1교', '지품9터널(청주외부)', '갈평육교', '상주분기점', '미천교', '양곡교', '묵계1교', '상주휴게소', '사일산터널(청주외부2)', '지품3터널(청주외부)', '회인', '수리티교', '단밀2터널(청주외부)', '영덕터널(청주외부)', '안평1터널(청주외부1)', '동안동', '지품2터널(영덕외부)', '청송', '장림천교', '안평2터널(영덕외부)', '갈평교', '문의휴게소1', '청주분기점', '구병산교', '문의휴게소', '길안3터널(영덕외부1)', '수한터널', '회인터널(상주)-외부', '길안4터널(청주외부)', '운평1교', '지품2터널(청주외부)', '길안1터널(청주외부)', '성암교', '파천3터널(영덕외부2)', '서변1교', '문의', '상주쉼터(상주)', '남상주', '지품7터널(청주외부)', '서원4교', '지품8터널(청주외부)', '척산1', '문의2터널(상주)-외부', '진보터널(청주외부)', '안평1터널(청주외부2)', '척산', '지품2교', '탄부터널', '사일산터널(청주외부1)', '지품8터널(영덕외부)', '단촌2터널', '지품7터널(영덕외부)', '안평2터널(영덕외부2)', '내서3터널(청주)-외부', '삼가천교', '단촌4터널(청주외부2)', '화서휴게소', '안사2터널(청주외부)', '안동분기점', '지품10터널(영덕외부)', '지사교', '달천1교', '서원1교', '문동', '파천2터널(청주외부)', '내서3터널(상주)-외부', '지품1터널(청주외부)', '평온교', '나각산터널(영덕외부)', '내서1교', '동청송영양', '단촌철교', '옥산터널', '길안1터널', '서원3교', '사일산터널(영덕외부)', '가덕', '단촌1터널', '속리산휴게소', '신촌', '달산2터널(영덕외부1)', '지천4교', '평각3교', '단촌4터널(청주외부1)', '피반령터널(청주)-외부', '의성SA', '보은', '단밀4터널(청주외부)', '단밀1터널', '파천3터널(청주외부)', '문의1터널(상주)-외부', '동상주', '낙동분기점_청주상주', '지품3터널(영덕외부)', '상주쉼터(청주)', '탄부', '복곡2교', '서재교', '성리교', '길안천교', '지품10터널(청주외부)', '파천1터널(청주외부2)', '단촌3터널(영덕외부)', '문의1터널(상주2)', '내서1터널', '안사1터널(영덕외부)', '금산리', '북의성', '서의성', '속리산', '안평3터널(청주외부)', '점곡SA(영덕)', '소양천교', '의암교', '마이산 졸음쉼터(익산)', '진안1터널', '오천1교', '[익산]장수터널(익산외부)', '고산천교', '물곡교', '[장수]곰티터널(장수외부)', '화심1교', '[익산]곰티터널(익산외부)', '연장2교', '진안교', '[익산]부귀2터널(익산외부)', '완주휴게소', '노평', '명덕1교', '진안', '[장수]부귀1터널(장수외부)', '익산분기점2', '[익산]상관2터널(익산외부)', '마이산 졸음쉼터(장수)', '진안휴게소', '방곡터널익산외부(고정)', '오천2교', '곰티터널익산#10(고정)', '신탁2교', '완주', '명덕2교', '석전', '완주분기점2', '장수_익산포항', '장수터널익산#3(고정)', '소양', '구룡2교', '단양1교', '[장수]방곡터널(장수외부)', '연장1교', '완주분기점_익산장수', '상관교', '의암교', '익산분기점2', '마이산 졸음쉼터(익산)', '노평', '진안1터널', '진안휴게소', '오천1교', '완주분기점_익산장수', '물곡교', '[장수]곰티터널(장수외부)', '화심1교', '완주분기점2', '[익산]곰티터널(익산외부)', '완주', '[장수]장수터널(장수외부)', '연장2교', '고산천교', '진안교', '장수_익산포항', '소양', '완주휴게소', '명덕1교', '[장수]부귀1터널(장수외부)', '곰티터널장수#3(고정)', '진안', '마이산 졸음쉼터(장수)', '방곡터널익산외부(고정)', '오천2교', '소양천교', '신탁2교', '장수터널장수#7(고정)', '명덕2교', '석전', '구룡2교', '단양1교', '[장수]방곡터널(장수외부)', '연장1교', '상관교', '석문령터널서측', '양주IC', '석문령터널동측', '옥정IC', '석문령터널서측', '양주IC', '옥정IC', '석문령터널동측', '신월천교', '산곡분기점', '가산교', '화산', '중부1터널', '낙타고개1', '진천쉼터(하남)', '일죽쉼터(남이)', '동서울영업소', '남이천', '용면교', '미호천', '오창 졸음쉼터', '하남', '마장분기점_중부', '증평', '후안2교', '일죽', '진천터널2', '경기광주분기점1', '서청주', '백곡천교', '초평교', '청용', '평동육교', '삼호교', '일죽쉼터(하남)', '여천교', '비하', '호법분기점_중부', '광주', '상산곡교',  ...
# 5841

# %%
a = os.listdir('./cctvImg')
nm = pd.DataFrame()

for i in a:
    nm1 = []
    nm2 = []
    if i == '.DS_Store':
        os.remove('./cctvImg/' + i)        
        
    try:
        for j in os.listdir('./cctvImg/'+ i + '/1'):
            if j == '.DS_Store':
                print('j1',i,j)                
                os.remove('./cctvImg/' + i + '/' + j)
            
            nm1.append(j[:-4].strip())            
        nm1 = pd.DataFrame(nm1,columns=[i+'1'])
        for j in os.listdir('./cctvImg/'+ i + '/2'):
            if j == '.DS_Store':
                print('j2',i,j)                
                os.remove('./cctvImg/' + i + '/' + j)
            nm2.append(j[:-4].strip())            
        nm2 = pd.DataFrame(nm2,columns=[i+'2'])
    except Exception as e:
        print('e',e)
    nm = pd.concat([nm1,nm2],axis = 1)        
    print(nm)
    nm.to_csv(i+'cctv')

# print(len(nm))
# Out:
#            청주영덕선1        청주영덕선2
# 0             상곡교         단밀2터널
# 1           단밀2터널           문의교
# 2             문의교  파천1터널(청주외부1)
# 3    파천1터널(청주외부1)            화서
# 4             문동1           상곡교
# ..            ...           ...
# 124         동청송영양           속리산
# 125         청주분기점   안평3터널(청주외부)
# 126   안평3터널(청주외부)      점곡SA(영덕)
# 127      점곡SA(영덕)           NaN
# 128           남상주           NaN
#
# [129 rows x 2 columns]
#              익산장수선1           익산장수선2
# 0              소양천교              의암교
# 1               의암교           익산분기점2
# 2      마이산 졸음쉼터(익산)     마이산 졸음쉼터(익산)
# 3             진안1터널               노평
# 4              오천1교            진안1터널
# 5    [익산]장수터널(익산외부)            진안휴게소
# 6              고산천교             오천1교
# 7               물곡교       완주분기점_익산장수
# 8    [장수]곰티터널(장수외부)              물곡교
# 9              화심1교   [장수]곰티터널(장수외부)
# 10   [익산]곰티터널(익산외부)             화심1교
# 11             연장2교           완주분기점2
# 12              진안교   [익산]곰티터널(익산외부)
# 13  [익산]부귀2터널(익산외부)               완주
# 14            완주휴게소   [장수]장수터널(장수외부)
# 15               노평             연장2교
# 16             명덕1교             고산천교
# 17               진안              진안교
# 18  [장수]부귀1터널(장수외부)          장수_익산포항
# 19           익산분기점2               소양
# 20  [익산]상관2터널(익산외부)            완주휴게소
# 21     마이산 졸음쉼터(장수)             명덕1교
# 22            진안휴게소  [장수]부귀1터널(장수외부)
# 23     방곡터널익산외부(고정)     곰티터널장수#3(고정)
# 24             오천2교               진안
# 25    곰티터널익산#10(고정)     마이산 졸음쉼터(장수)
# 26             신탁2교     방곡터널익산외부(고정)
# 27               완주             오천2교
# 28             명덕2교             소양천교
# 29               석전             신탁2교
# 30           완주분기점2     장수터널장수#7(고정)
# 31          장수_익산포항             명덕2교
# 32     장수터널익산#3(고정)               석전
# 33               소양             구룡2교
# 34             구룡2교             단양1교
# 35             단양1교   [장수]방곡터널(장수외부)
# 36   [장수]방곡터널(장수외부)             연장1교
# 37             연장1교              상관교
# 38       완주분기점_익산장수              NaN
# 39              상관교              NaN
#    구리포천지선1  구리포천지선2
# 0  석문령터널서측  석문령터널서측
# 1     양주IC     양주IC
# 2  석문령터널동측     옥정IC
# 3     옥정IC  석문령터널동측
#           중부선1      중부선2
# 0         신월천교  오창쉼터(남이)
# 1        산곡분기점        진천
# 2          가산교       월정교
# 3           화산       곤지암
# 4        중부1터널      신월천교
# ..         ...       ...
# 72  진천터널외부(남이)      화봉육교
# 73          모가     이천휴게소
# 74        화봉육교      평동육교
# 75       이천휴게소       초월1
# 76         상산곡        안평
#
# [77 rows x 2 columns]
#               영동선1           영동선2
# 0              양상교            멱곡리
# 1    대관령5터널(인천)-외부  대관령4터널(강릉)-외부
# 2              상대리            상대리
# 3        문막휴게소(인천)      문막휴게소(인천)
# 4             거모2교             속사
# ..             ...            ...
# 207            이목정          평창IC교
# 208          양지제일리          면온정류장
# 209           노림리1           동백교3
# 210            우용리             이천
# 211             양지           월곶1교
#
# [212 rows x 2 columns]
# Empty DataFrame
# Columns: [서울문산지선1, 서울문산지선2]
# Index: []
#              옥산오창선1           옥산오창선2
# 0       서오창영업소 6.6K  경부선(하) 옥산JC 진출부
# 1              호죽2교             호죽2교
# 2         서오창영업소 6K             오창JC
# 3              오창JC      서오창영업소 6.6K
# 4              병천천교        서오창영업소 6K
# 5              복현1교             병천천교
# 6   경부선(상) 옥산JC 진출부             복현1교
# 7               산수교  경부선(상) 옥산JC 진출부
# 8              호죽1교              산수교
# 9               양지교             호죽1교
# 10              성산교              성산교
# 11  경부선(하) 옥산JC 진출부              양지교
#        대구부산선1     대구부산선2
# 0       남천 원리      남천 원리
# 1       고정3터널      고정3터널
# 2       청도천5교       대포천교
# 3        대포천교      청도휴게소
# 4   고정2터널(부산)      청도1터널
# 5       청도휴게소       밀양IC
# 6       남밀양IC       남천하도
# 7        남천하도  무척산터널(대구)
# 8        옥곡1교      삼랑진IC
# 9        낙동대교       옥곡1교
# 10        평촌교      청도천5교
# 11       남천터널  생림2터널(대구)
# 12       상동IC        평촌교
# 13       수성욱수       남천터널
# 14        금시교        금시교
# 15      청도 원정       밀양대교
# 16      상동 감로      남밀양IC
# 17      고정1터널      대동분기점
# 18       밀양대교       수성욱수
# 19       삼성2교       낙동대교
# 20      상동2터널  고정2터널(대구)
# 21       밀양IC      청도 원정
# 22       남천대교      동대구IC
# 23      대동분기점       수성IC
# 24      삼랑진IC      상동 감로
# 25       청도IC      고정1터널
# 26     동대구분기점       삼성2교
# 27      동대구IC       남천대교
# 28      청도2터널       상동IC
# 29  생림2터널(부산)      생림1터널
# 30       고정대교      청도2터널
# 31       밀양강교     동대구분기점
# 32       용산터널       청도IC
# 33        송읍교       고정대교
# 34       덕산쉼터       밀양강교
# 35       가곡터널       용산터널
# 36       수성IC        송읍교
# 37       가천쉼터       덕산쉼터
# 38        NaN       가곡터널
# 39        NaN       가천쉼터
#      평택시흥선1   평택시흥선2
# 0       정든교      정든교
# 1     군자R-A    군자R-A
# 2    공룡알화석지     용포1교
# 3   송산포도휴게소   공룡알화석지
# 4       석교교     송산마도
# 5      신길천교      남안산
# 6      송산마도  송산포도휴게소
# 7       남안산      석교교
# 8      주곡1교     신길천교
# 9       장덕교     주곡1교
# 10      청원교      장덕교
# 11    군자R-B      청원교
# 12   서평택JCT     고정2교
# 13     고정2교     음섬2교
# 14     음섬2교      남양교
# 15      남양교     시화대교
# 16     시화대교       조암
# 17       조암    독정2육교
# 18    독정2육교   서평택JCT
# 19    장안영업소    장안영업소
# 20    금의1육교    금의1육교
# 21     수촌1교     수촌1교
# 22     용포1교    군자R-B
#         동해선(삼척-속초)1      동해선(삼척-속초)2
# 0              쇄운교2             쇄운교2
# 1          강릉분기점_동해            상왕도1교
# 2             상왕도1교             주수천교
# 3               적노교              적노교
# 4       근덕터널(삼척 외부)               근덕
# ..              ...              ...
# 81              초구교             낙풍3교
# 82           북강릉영업소              상광정
# 83  [삼척]청대터널(삼척 외부)               옥계
# 84            북양양IC  [삼척]청대터널(삼척 외부)
# 85              임호정              NaN
#
# [86 rows x 2 columns]
#       부산울산선1    부산울산선2
# 0      고래진1교     고래진1교
# 1         문수        문수
# 2      장안휴게소      삼정천교
# 3       청강3교     장안휴게소
# 4       원리1교      청강3교
# 5        내리교      원리1교
# 6         장안       내리교
# 7        만화교       만화교
# 8       장안천교        장안
# 9         일광      장안천교
# 10      고산육교      고산육교
# 11       삼정리        온양
# 12      남창천교    울산분기점2
# 13        망양        일광
# 14    울산분기점1      좌광천교
# 15        온양       해운대
# 16      삼정천교        망양
# 17      좌광천교    울산분기점1
# 18      회야대교        청량
# 19    울산분기점2     고래진2교
# 20      대운천교      회야대교
# 21      청강2교      대운천교
# 22       해운대  횡계리_부산울산
# 23  횡계리_부산울산       용소교
# 24       용소교       장안리
# 25       장안리       삼정리
# 26        청량      청강2교
# 27     고래진2교      남창천교
#      중앙선1  중앙선2
# 0    백운2교  백운2교
# 1     장평리   장평리
# 2    다부1교  광격2교
# 3    광격2교   국곡교
# 4     국곡교   노동교
# ..    ...   ...
# 168    안평  금대4교
# 169   남제천  원창3교
# 170  대사3교    안평
# 171   NaN  대사3교
# 172   NaN  수서1교
#
# [173 rows x 2 columns]
#    남해1지선1 남해1지선2
# 0     동마산  마산영업소
# 1      산인    동마산
# 2     두곡교     용강
# 3   내서분기점   중리육교
# 4    중리육교   광려천교
# 5    광려천교    서마산
# 6     용담2    두곡교
# 7     합성교    초계교
# 8     초계교    용담2
# 9     서마산    합성교
# 10   구암1교   구암1교
# 11   솔티고개   솔티고개
# 12    용담1    용담1
# 13  마산영업소  내서분기점
# 14   두척천교   두척천교
# 15   창원고개     산인
# 16     용강   창원고개
# 17   산인고개   산인고개
# 18   용담육교   용담육교
#      광주원주선1   광주원주선2
# 0       삼산교    서원주IC
# 1     신평JCT    원주JCT
# 2       장풍리   남한강대교2
# 3      초현1교      장풍리
# 4   경기광주휴게소     초현1교
# 5    광주JCT1    동양평IC
# 6     원주영업소    원주영업소
# 7    동곤지암IC    동여주IC
# 8      송현1교   동곤지암IC
# 9     원주JCT   광주JCT1
# 10    양평휴게소     판대2교
# 11    동여주IC     도곡1교
# 12      하오개    신평JCT
# 13      무장리    대신터널2
# 14     판대2교     송현1교
# 15    서원주IC    양평휴게소
# 16   남한강대교2      하오개
# 17    대신터널2      무장리
# 18   흥천이포IC      삼산교
# 19    대신터널1  경기광주휴게소
# 20     도곡1교    대신터널1
# 21     성지지맥     성지지맥
# 22    동양평IC     대신IC
# 23   광주JCT2   광주JCT2
# 24   남한강대교1   남한강대교1
# 25     대신IC   흥천이포IC
#        상주영천선1     상주영천선2
# 0        달산1교        효지교
# 1      원당교(1)        가호교
# 2         효지교        상원교
# 3         가호교   군위터널(영천)
# 4         상원교       고현천교
# 5        북안IC        대곡교
# 6    군위터널(영천)      화산JCT
# 7        고현천교       달산1교
# 8         대곡교        장곡교
# 9         오미교     도개교(1)
# 10      화산JCT      동군위IC
# 11       신녕IC      군위JCT
# 12        장곡교        금매교
# 13     도개교(1)   중구터널(영천)
# 14   중구터널(영천)      서군위IC
# 15        금매교        대성교
# 16      동영천IC        창정교
# 17      서군위IC       다곡1교
# 18        창평교        상촌교
# 19        대성교        오실교
# 20       도개IC   효령터널(상주)
# 21       삼부천교   군위터널(상주)
# 22        창정교     도개교(2)
# 23       다곡1교       신녕IC
# 24        오실교        화계교
# 25   효령터널(상주)        효령교
# 26   군위터널(상주)       달산2교
# 27     도개교(2)   평호터널(영천)
# 28        화계교       화남2교
# 29        효령교       북안IC
# 30       달산2교        창평교
# 31   평호터널(영천)        장기교
# 32        상촌교      낙동JCT
# 33       화남2교   산법터널(상주)
# 34        장기교        치산교
# 35   산법터널(상주)   군위애플졸음쉼터
# 36        치산교  삼국유사군위(휴)
# 37   군위애플졸음쉼터        산하교
# 38      상주JCT        가천교
# 39  삼국유사군위(휴)        오미교
# 40        산하교        신개교
# 41      동군위IC      군위왜가리
# 42        신개교      상주JCT
# 43      군위왜가리       도개IC
# 44      낙동JCT      동영천IC
# 45    낙동의성휴게소    낙동의성휴게소
# 46        화남교        화남교
# 47        가천교        목골교
# 48      군위JCT        부산교
# 49        목골교        오로교
# 50        부산교     원당교(1)
# 51        오로교     영천졸음쉼터
# 52     영천졸음쉼터       삼부천교
#         제2중부선1      제2중부선2
# 0     경기광주분기점2    경기광주분기점2
# 1        진우1육교       진우1육교
# 2   마장분기점_제2중부  마장분기점_제2중부
# 3          하번천          신둔
# 4           초월     선동_제2중부
# 5          엄미교         하번천
# 6         천진암교     상번천졸음쉼터
# 7           신둔        곤지암2
# 8         곤지암2          초월
# 9         신월1교        궁평1교
# 10        목동1교        천진암교
# 11     선동_제2중부       광지원터널
# 12     상번천졸음쉼터        경안천교
# 13        궁평1교         엄미교
# 14       광지원터널        신월1교
# 15        경안천교         NaN
#            수도권제1순환선1    수도권제1순환선2
# 0               별내IC       성남졸음쉼터
# 1            소래터널-시흥  노고1터널(일산방향)
# 2             구리졸음쉼터      소래터널-시흥
# 3           시흥하늘휴게소2   사패터널(일산방향)
# 4             성남삼평교2     시흥하늘휴게소2
# ..               ...          ...
# 95  [판교1]광암터널(판교1 2)     시흥하늘휴게소1
# 96             성남요금소       성남삼평교2
# 97             거여고가교   수락터널(일산방향)
# 98             청계운중교        서운분기점
# 99          시흥하늘휴게소1          NaN
#
# [100 rows x 2 columns]
#       경인선1    경인선2
# 0       부천      부천
# 1      가정동      부평
# 2       도당      도당
# 3   서운분기점2    신월-1
# 4      신월2  서운분기점2
# 5       효성      효성
# 6     도당육교    도당육교
# 7       부평   인천영업소
# 8       신월     신월2
# 9    인천영업소     청천교
# 10    신월-1     도당2
# 11     청천교      신월
# 12     도당2     가정동
#               고창담양선1            고창담양선2
# 0                부흥교              장산2교
# 1               장성물류        대덕분기점_고창담양
# 2               장산2교              상림육교
# 3               상림육교               은사교
# 4                은사교               부흥교
# 5          문수산터널고창#9         장성3터널담양#2
# 6         장성분기점_고창담양        장성분기점_고창담양
# 7                북광주   [담양]장성2터널(담양외부)
# 8          장성3터널고창#9              장성물류
# 9    [고창]장성3터널(고창외부)                와우
# 10               남고창              용강2교
# 11           고수(절토부)         문수산터널담양#6
# 12                와우               남고창
# 13  [담양]문수산터널(담양외부2)               북광주
# 14        대덕분기점_고창담양   [담양]문수산터널(담양외부)
# 15               장화교                해곡
# 16   [고창]문수산터널(고창외부)   [고창]문수산터널(고창외부)
# 17              용강2교   [담양]장성3터널(담양외부)
# 18   [고창]장성2터널(고창외부)           고수(절토부)
# 19                해곡  [담양]문수산터널(담양외부2)
# 20               NaN               장화교
#          동해선(부산-포항)1       동해선(부산-포항)2
# 0   [포항]범서1터널(포항외부1)              범서대교
# 1   [울산]양북1터널(울산 16)  [포항]범서1터널(포항외부1)
# 2   [포항]범서3터널(포항외부1)              외동1교
# 3               외동1교        오천4터널(외부1)
# 4                 문덕  [포항]범서3터널(포항외부3)
# 5                남경주  [포항]오천6터널(포항외부3)
# 6         오천4터널(외부1)          오천6(외부1)
# 7               범서대교                문덕
# 8           오천6(외부1)               남포항
# 9   [울산]다운1터널(울산외부1)  [울산]범서4터널(울산외부1)
# 10               남포항               두산교
# 11  [울산]범서4터널(울산외부1)               남경주
# 12               동경주          양북5(외부1)
# 13               두산교                입천
# 14  [포항]양북1터널(포항 외부)  [포항]오천2터널(포항외부1)
# 15          양북5(외부1)                범서
# 16  [포항]오천6터널(포항외부2)  [포항]외동2터널(포항외부1)
# 17                입천  [포항]양북1터널(포항 외부)
# 18  [포항]범서3터널(포항외부2)             시무내천교
# 19  [포항]오천2터널(포항외부1)  [포항]오천3터널(포항외부2)
# 20  [포항]외동2터널(포항외부1)  [포항]범서2터널(포항외부1)
# 21  [포항]범서2터널(포항외부1)              대종천교
# 22              대종천교  [울산]오천5터널(울산외부1)
# 23  [울산]오천5터널(울산외부1)          오천1(외부1)
# 24          오천1(외부1)  [포항]양북3터널(포항외부3)
# 25  [포항]양북3터널(포항외부3)               동경주
# 26  [울산]외동3터널(울산외부1)              신광천교
# 27                범서              다운2교
# 28              신광천교  [울산]외동2터널(울산외부1)
# 29              다운2교  [포항]양북1터널(포항 17)
# 30  [울산]외동2터널(울산외부1)  [포항]다운4터널(포항외부1)
# 31  [포항]양북1터널(포항 17)        양북3(포항외부1)
# 32        양북3(포항외부1)  [포항]양북3터널(포항외부2)
# 33             시무내천교              냉천3교
# 34  [포항]양북3터널(포항외부2)  [포항]범서3터널(포항외부1)
# 35  [포항]오천3터널(포항외부1)  [울산]오천7터널(울산외부1)
# 36              냉천3교  [울산]오천5터널(울산외부2)
# 37  [울산]오천7터널(울산외부1)               NaN
# 38  [울산]오천5터널(울산외부2)               NaN
#         평택화성선1      평택화성선2
# 0       북평택영업소      정남괘랑2교
# 1   봉담방음터널(봉담)       정남용수교
# 2           봉담      서오산분기점
# 3       정남괘랑2교          오성
# 4        정남고지리          봉담
# 5          향남교       정남고지리
# 6     봉담터널(화성)      봉담분천2교
# 7        정남용수교          정남
# 8         어연IC      북평택영업소
# 9        양감정문리         향남교
# 10          정남          향남
# 11      서오산분기점        어연IC
# 12  평택분기점_평택화성       양감정문리
# 13      봉담분천2교  평택분기점_평택화성
# 14          향남  봉담방음터널(봉담)
# 15          오성     청북_평택화성
# 16     청북_평택화성       정남망월리
# 17       정남망월리         NaN
#           수원광명선1        수원광명선2
# 0        수리산3터널앞       수리산3터널앞
# 1          동시흥JC         동시흥JC
# 2   구봉산터널입구_수원방향  구봉산터널입구_수원방향
# 3        수리산2터널앞       수리산2터널앞
# 4           소하IC          소하IC
# 5          남광명JC         남광명JC
# 6       금곡지하차도입구      금곡지하차도입구
# 7          성채터널앞         성채터널앞
# 8           양달2교          양달2교
# 9       수리산1터널입구      수리산1터널입구
# 10      성채터널(수원)      성채터널(수원)
# 11  구봉산터널입구_광명방향  구봉산터널입구_광명방향
# 12       동안산당수IC       동안산당수IC
# 13          금곡IC          금곡IC
# 14         남군포IC         남군포IC
# 15            시점            시점
# 16        수리산3터널        수리산3터널
#                통영대전선1           통영대전선2
# 0                  대곡            적상천2교
# 1                 서하교               대곡
# 2                  장문  [대전]함양터널(대전외부1)
# 3                  죽림               장계
# 4    [통영]육십령터널(통영외부2)              서하교
# ..                ...              ...
# 129             사천3터널            산청1터널
# 130               NaN            산청휴게소
# 131               NaN            진주분기점
# 132               NaN               대포
# 133               NaN            사천3터널
#
# [134 rows x 2 columns]
#          서천공주선1       서천공주선2
# 0           경둔리          경둔리
# 1            추동           추동
# 2           정동교          정동교
# 3        동서천분기점       동서천분기점
# 4          금천1교         금천1교
# 5          마산1교         마산1교
# 6          장평2교         장평2교
# 7       부여백제휴게소      부여백제휴게소
# 8         부여2터널        부여2터널
# 9           풍정교          풍정교
# 10          가공교          가공교
# 11           용봉           용봉
# 12   시초졸음쉼터(공주)   시초졸음쉼터(공주)
# 13         앵봉터널         앵봉터널
# 14          안심교          안심교
# 15          수목교          수목교
# 16          금사교          금사교
# 17          상장교          상장교
# 18           내지           내지
# 19           지산           지산
# 20        동서천IC        동서천IC
# 21  서공주분기점_서천공주  서공주분기점_서천공주
# 22         보흥1교         보흥1교
# 23         청남대교         청남대교
# 24           보흥           보흥
# 25           은곡           은곡
# 26           은산           은산
# 27           현암           현암
# 28          황사교          황사교
# 29           가중           가중
# 30           청양           청양
# 31    용봉2교_서천공주    용봉2교_서천공주
# 32         신성1교         신성1교
# 33          서부여          서부여
# 34           부여           부여
# 35           이사           이사
# 36         교원천교         교원천교
# 37         수목천교         수목천교
# 38   부여졸음쉼터(공주)   부여졸음쉼터(공주)
# 39           상장           상장
# 40          안상교          안상교
# 41          팔지교          팔지교
# 42         신흥1교         신흥1교
# 43          대흥교          대흥교
# 44          서공주          서공주
# 45     청남대교(고정)     청남대교(고정)
# 46         유구천교         유구천교
# 47        청양휴게소        청양휴게소
#      서해안선1   서해안선2
# 0       비봉   함평휴게소
# 1       고창     춘장대
# 2    함평휴게소      초대
# 3       초대     율암교
# 4      율암교  주탑케이블6
# ..     ...     ...
# 196     석정      관상
# 197     관상      장년
# 198     장년      여미
# 199   당진1교   춘장대쉼터
# 200  춘장대쉼터     NaN
#
# [201 rows x 2 columns]
#            호남지선1         호남지선2
# 0            자운대            논산
# 1          금곡천교2           자운대
# 2             계룡         금곡천교1
# 3          금곡천교1      유성쉼터(회덕)
# 4       유성쉼터(회덕)          설목육교
# 5           설목육교          대정육교
# 6           대정육교            야촌
# 7           강청육교          강청육교
# 8          벌곡휴게소        서대전분기점
# 9           두계천교         벌곡휴게소
# 10       서대전분기점2          두계천교
# 11            야촌          자운육교
# 12          금곡천교       서대전분기점2
# 13            녹산          금곡천교
# 14     북대전쉼터(회덕)            녹산
# 15         벌곡정류장     북대전쉼터(회덕)
# 16            유성         벌곡정류장
# 17     북대전쉼터(논산)        서대전쉼터1
# 18        서대전쉼터1           탄동교
# 19           탄동교          논산천교
# 20          논산천교            조령
# 21        서대전분기점            소룡
# 22          복용육교          죽평육교
# 23            소룡            죽동
# 24            전민            전민
# 25    유성분기점_호남지선            유성
# 26            죽동            양촌
# 27            논산          탑립육교
# 28            양촌          복용육교
# 29          탑립육교           북대전
# 30           북대전         금곡천교2
# 31            조령            계룡
# 32          죽평육교    유성분기점_호남지선
# 33          자운육교  서대전졸음쉼터2(논산)
# 34  서대전졸음쉼터2(논산)          양촌고개
# 35          양촌고개           NaN
#       부산신항선1     부산신항선2
# 0      진례분기점      진해영업소
# 1  제2배후도로 시점      소사천1교
# 2  장유2터널(김해)      진례분기점
# 3      진해영업소  장유2터널(김해)
# 4       장유1교       대청IC
# 5  장유2터널(신항)  장유2터널(신항)
# 6   장유1터널진입부  제2배후도로 시점
# 7       남문대교   장유1터널진입부
# 8       대청IC       남문대교
# 9      소사천1교       장유1교
#        제3경인선1      제3경인선2
# 0       도리JCT        목감IC
# 1        목감IC       월곶JCT
# 2       월곶JCT       도리JCT
# 3        연성IC        연성IC
# 4  군자대교(정왕IC)  군자대교(정왕IC)
#            제2경인선1         제2경인선2
# 0      금토대교전방400M          문학경기장
# 1          금토대교종점  [안양]광명터널(안양3)
# 2              남동   북판교영업소전방400M
# 3    북판교영업소전방400M             신천
# 4          안현분기점2           여수대로
# 5        삼막IC(성남)           학익대교
# 6            학익대교     금토대교전방400M
# 7              신천             일직
# 8   [인천]광명터널(인천3)           청계IC
# 9       북의왕IC(안양)         제2경인시점
# 10         안현분기점1      북의왕IC(안양)
# 11      동판교IC(본선)      동판교IC(본선)
# 12       청계산2-3터널         안현분기점1
# 13           청계IC       청계산2-3터널
# 14           은행3교         금토대교종점
# 15             문학        광명_제2경인
# 16    안양과천영업소(안양)         안현분기점2
# 17           광명터널           은행3교
# 18          문학경기장             문학
# 19       청계산3-4터널           광명터널
# 20        광명_제2경인       청계산3-4터널
# 21        남인천영업소1        남인천영업소1
# 22           여수대로             석수
# 23             석수          서창분기점
# 24          서창분기점            남인천
# 25            남인천       삼막IC(성남)
# 26             일직             남동
# 27         제2경인시점            NaN
#       인천김포선1    인천김포선2
# 0      북청라대교    검단양촌IC
# 1    청라원창영업소     북청라대교
# 2   인천북항터널남측      학운1교
# 3      북청라대교  인천북항터널남측
# 4   인천항고가교남측   청라원창영업소
# 5    서김포통진IC     북청라대교
# 6       대곶IC      대능2교
# 7     검단양촌IC     북청라IC
# 8      북청라IC   서김포통진IC
# 9       학운1교  인천항고가교남측
# 10      대능2교      대곶IC
#       봉담동탄선1       봉담동탄선2
# 0      북오산IC        오산서랑동
# 1      오산서랑동    필봉산터널(봉담)
# 2      동탄금곡교        동탄금곡교
# 3     동탄오산천교  세교방음터널2(봉담)
# 4   동탄JC(동탄)        북오산IC
# 5  필봉산터널(동탄)        오산지곶교
# 6      오산지곶교       동탄오산천교
#                 무안광주선1              무안광주선2
# 0                 무안공항                  월산
# 1       [무안]보평터널(무안외부)                동산육교
# 2              함평나비휴게소                  문평
# 3                  북무안      [광주]보평터널(광주외부)
# 4                   나주    [광주]함평나비터널(광주외부)
# 5                   문평  [무안]어등산호남대터널(무안외부)
# 6                 계림육교                 서광산
# 7                  동광산                  현경
# 8                  광산교                  마산
# 9       [광주]보평터널(광주외부)  [광주]어등산호남대터널(광주외부)
# 10                  현경                 동함평
# 11                  마산                대도2교
# 12  [광주]어등산호남대터널(광주외부)      [광주]노안터널(광주외부)
# 13                대도2교                계림육교
# 14      [무안]노안터널(무안외부)                 동광산
# 15                 서광산                  나주
# 16    [무안]함평나비터널(무안외부)                무안공항
# 17                동산육교             함평나비휴게소
# 18                 동함평                  용곡
# 19                  용곡                 광산교
# 20                  월산                 북무안
# 21  [무안]어등산호남대터널(무안외부)                 NaN
#               순천완주선1            순천완주선2
# 0                 임실               대치교
# 1   [순천]구례1터널(순천외부1)  [순천]구례1터널(순천외부1)
# 2                서남원               지당교
# 3   [순천]용방2터널(순천외부1)               정송교
# 4                정송교  [완주]서면5터널(완주외부1)
# ..               ...               ...
# 81       용암4터널외부순천#1  [완주]서면2터널(완주외부1)
# 82                황전               NaN
# 83  [완주]사매4터널(외부완주1)               NaN
# 84              어은천교               NaN
# 85  [완주]서면2터널(완주외부1)               NaN
#
# [86 rows x 2 columns]
#           경부선1       경부선2
# 0       남이분기점2      옥산휴게소
# 1        옥산휴게소       용장초교
# 2         용장초교         죽전
# 3      낙동대교_경부    낙동대교_경부
# 4          신탄진     도동분기점2
# ..         ...        ...
# 303       외동천교         공도
# 304         대룡  회덕분기점(고정)
# 305         구서        NaN
# 306         공도        NaN
# 307  회덕분기점(고정)        NaN
#
# [308 rows x 2 columns]
#    오산화성선1  오산화성선2
# 0    안녕IC    안녕IC
# 1  서오산영업소  서오산영업소
#            중부내륙지선1       중부내륙지선2
# 0          (구)달성터널           성서2
# 1        구달성터널 공단로            송촌
# 2   [현풍]달성1터널(현풍5)     구달성터널 공단로
# 3              남대구       (구)달성터널
# 4              성서3        옥포분기점2
# 5        달성2터널(현풍)     달성2터널(현풍)
# 6             논공단지          논공단지
# 7               송촌           남대구
# 8              용산2            유천
# 9            현풍휴게소         현풍휴게소
# 10              성서        옥포분기점3
# 11              월암            성서
# 12             성서2           용산2
# 13           현풍1육교            화원
# 14              본리           서대구
# 15              달성            본리
# 16             용산동           용산동
# 17            논공남리          논공남리
# 18    옥포분기점_중부내륙지선  옥포분기점_중부내륙지선
# 19          옥포분기점2           성서3
# 20             서대구         현풍1육교
# 21       유천 하이패스IC            달성
# 22              화원         달성2터널
# 23           달성2터널            월암
# 24              유천          서대구2
# 25          옥포분기점3           NaN
# 26            서대구2           NaN
#            인천공항선1         인천공항선2
# 0          북인천영업소             시점
# 1         서울 20.2        인천공항영업소
# 2          노오지분기점         북인천영업소
# 3   방화대교남단(올림픽대로)  방화대교남단(올림픽대로)
# 4    방화대교북단(강변북로)         노오지분기점
# 5           김포나들목   방화대교북단(강변북로)
# 6        공항입구 나들목          김포나들목
# 7            영종대교       공항입구 나들목
# 8          영종대교종점           영종대교
# 9              시점        공항 25.2
# 10        인천공항영업소        서울 20.2
# 11      공항신도시 나들목         영종대교종점
# 12         개화터널입구      공항신도시 나들목
# 13        공항 25.2         금산 나들목
# 14         영종대교시점         개화터널입구
# 15         금산 나들목         영종대교시점
# Empty DataFrame
# Columns: [인천대교선1, 인천대교선2]
# Index: []
#         용인서울선1       용인서울선2
# 0       광교상현IC           고등
# 1           고등    심곡터널입구 서울
# 2      흥덕IC 수원    신대지하차도 서울
# 3         동천육교         동천육교
# 4         금토1교         길마재교
# 5         고등IC  하산운터널 서울 출구
# 6         길마재교       광교상현IC
# 7           심곡         금토1교
# 8         금토TG         고등IC
# 9    신대지하차도 수원           심곡
# 10       서분당IC      흥덕IC 서울
# 11        헌릉IC  하산운터널 서울 중앙
# 12  서판교IC진입 수원      고기터널 서울
# 13       서수지IC         금토TG
# 14         NaN        서분당IC
# 15         NaN         헌릉IC
# 16         NaN    세곡터널입구 서울
# 17         NaN        서수지IC
#               대전남부선1             대전남부선2
# 0                서대전                 안영
# 1  [서대전]구봉터널(서대전 외부)  [서대전]구봉터널(서대전 외부)
# 2   [산내]안영1터널(산내 외부)   [산내]안영1터널(산내 외부)
# 3                 구봉               이사1교
# 4               구완터널                서대전
# 5                무수교               구완터널
# 6               무수2교                 구봉
# 7                 안영                무수교
# 8               이사1교               무수2교
#                서울양양선1            서울양양선2
# 0               화촌7터널             화촌7터널
# 1          천안터널외부(서울)                봉명
# 2       [서울]서석터널(서울3)               동홍천
# 3           동산1터널외부#1         동산1터널외부#1
# 4         월문3터널외부(서울)           남양주영업소3
# ..                ...               ...
# 122              이천2교  [양양]내촌3터널(양양외부1)
# 123    [양양]서면4터널(외부2)  [양양]상남3터널(양양외부1)
# 124    [서울]상남7터널(서울7)           발산4터널종점
# 125  [양양]상남3터널(양양외부1)               NaN
# 126           발산4터널종점               NaN
#
# [127 rows x 2 columns]
#              부산외곽선1           부산외곽선2
# 0              와여1교             와여1교
# 1              대포천교             대포천교
# 2              나전2교              퇴래천
# 3          광재IC(램프)             나전2교
# 4              철마IC  [기장]금정산터널(기장23)
# 5              진영IC            진영JCT
# 6             대감JCT         광재IC(램프)
# 7           기장일광영업소              하계교
# 8          진영JC(램프)             철마IC
# 9             진영JCT            대감JCT
# 10              하계교            김해휴계소
# 11  [창원]금정산터널(창원16)             진영IC
# 12            철마2터널             금정IC
# 13              백길교          기장일광영업소
# 14            김해휴계소             광재IC
# 15              퇴래천              백길교
# 16             금정IC            철마3터널
# 17             광재IC            철마2터널
# 18            철마3터널             노포JC
# 19             노포JC              연구교
# 20              연구교              용천교
# 21              용천교              NaN
#         서울문산선1      서울문산선2
# 0   CCTV#15 본선  CCTV#15 본선
# 1    CCTV#5 본선   CCTV#5 본선
# 2   CCTV#19 본선  CCTV#19 본선
# 3    CCTV#9 본선  CCTV#14 본선
# 4   CCTV#22 본선  CCTV#21 본선
# 5   CCTV#13 본선  CCTV#13 본선
# 6    CCTV#6 본선  CCTV#22 본선
# 7   CCTV#25 본선   CCTV#6 본선
# 8   CCTV#24 본선   CCTV#7 본선
# 9   CCTV#23 본선  CCTV#24 본선
# 10  CCTV#21 본선  CCTV#16 본선
# 11  CCTV#16 본선  CCTV#23 본선
# 12   CCTV#4 본선   CCTV#8 본선
# 13  CCTV#14 본선   CCTV#4 본선
# 14   CCTV#3 본선   CCTV#3 본선
# 15   CCTV#7 본선   CCTV#9 본선
# 16   CCTV#8 본선  CCTV#25 본선
# 17  CCTV#12 본선  CCTV#12 본선
# 18  CCTV#20 본선  CCTV#20 본선
#          광주대구선1      광주대구선2
# 0          고죽1교         기족교
# 1           기족교        옥율천교
# 2          옥율천교         건곡교
# 3          황강천교         내동교
# 4           건곡교        방축1교
# ..          ...         ...
# 124  쌍림터널(외부광주)  쌍림터널(외부광주)
# 125         정장교         정장교
# 126        광치천교        광치천교
# 127     춘전재 토석류  강천산휴게소(대구)
# 128         NaN     춘전재 토석류
#
# [129 rows x 2 columns]
#         남해선(영암-순천)1 남해선(영암-순천)2
# 0                보성          장흥
# 1             순천만1교       순천만1교
# 2   [영암]강진2터널(영암외부)    해룡터널영암외부
# 3          해룡터널영암외부        호계1교
# 4              호계1교     벌교대교_순천
# ..              ...         ...
# 58              순천만      남해금계1교
# 59          장동2,3터널         서영암
# 60              NaN       남해수암교
# 61              NaN        토마육교
# 62              NaN     장동2,3터널
#
# [63 rows x 2 columns]
#       울산선1     울산선2
# 0     울산종점     울산종점
# 1       입암    범서정류장
# 2     울산시점       입암
# 3     반연육교     울산시점
# 4    언양정류장     반연육교
# 5   울산졸음쉼터   울산졸음쉼터
# 6  사연교(관제)  사연교(관제)
# 7      사연교      사연교
# 8    범서정류장    언양정류장
# 9      반송교      반송교
#         당진대전선1      당진대전선2
# 0           목천          유구
# 1   유성분기점_당진대전  당진분기점_당진대전
# 2        공주분기점        사기소교
# 3          영곡2          면천
# 4          승지교          상장
# ..         ...         ...
# 61          화흥         녹문교
# 62         녹문교          신웅
# 63          신웅     안산_당진대전
# 64     안산_당진대전          손지
# 65          손지          월곡
#
# [66 rows x 2 columns]
#     남해선(순천-부산)1 남해선(순천-부산)2
# 0    진주2터널(외부2)  진주2터널(외부2)
# 1            죽평          죽평
# 2          방촌육교        방촌육교
# 3           망덕교         망덕교
# 4            광양         동석교
# ..          ...         ...
# 126       함안2터널          신금
# 127         NaN          선소
# 128         NaN        김해터널
# 129         NaN       함안2터널
# 130         NaN         대저2
#
# [131 rows x 2 columns]
#           남해2지선1        남해2지선2
# 0          서낙동강교         서낙동강교
# 1          서부산종점          조만강교
# 2         제1농로육교        제1농로육교
# 3   서부산 낙동강교(종점)  서부산 낙동강교(종점)
# 4           용산육교          용산육교
# 5           율하천교          율하천교
# 6            용산교          응달육교
# 7           응달육교        서부산영업소
# 8           조만강교           용산교
# 9             장유         서부산종점
# 10           순아교         장유휴게소
# 11        서부산영업소            장유
# 12           서부산           서부산
# 13          태정육교           순아교
# 14          용곡육교          수가육교
# 15            가락          태정육교
# 16           능동교          용곡육교
# 17         장유휴게소           능동교
# 18          수가육교            가락
#          평택제천선1       평택제천선2
# 0          가흥2교         가흥2교
# 1   산척3터널(평택외부)         남안성2
# 2            송탄  산척3터널(평택외부)
# 3           신니교          신니교
# 4          부윤리1         부윤리1
# ..          ...          ...
# 76         수태1교      광혜원졸음쉼터
# 77         양기3교         수태1교
# 78          공도교         양기3교
# 79          문숭리          공도교
# 80          NaN          문숭리
#
# [81 rows x 2 columns]
#       논산천안선1    논산천안선2
# 0       삼성3교      채운철교
# 1       신화2교      삼성3교
# 2        반촌교     남공주IC
# 3        신흥교      신화2교
# 4      남공주IC       신흥교
# 5        풍세교      탄천IC
# 6        우성교       우성교
# 7        검상교       검상교
# 8       논산천교      논산천교
# 9       탄천SA      탄천SA
# 10     용성천2교     용성천2교
# 11       인풍교       인풍교
# 12    북공주JCT    북공주JCT
# 13     공주JCT      정안IC
# 14     남천안IC      송정천교
# 15      연무IC       신당교
# 16       신당교     용성천1교
# 17     용성천1교     남천안IC
# 18       운궁교  255.4 km
# 19  255.4 km       운궁교
# 20      송정천교      연무IC
# 21      탄천IC       정안교
# 22       정안교      호정1교
# 23       광명교       광명교
# 24     천안JCT       반촌교
# 25      정안SA     공주JCT
# 26       마전교     천안JCT
# 27      호정1교      정안SA
# 28      무학천교       마전교
# 29      채운철교      무학천교
# 30  248.9 km  248.9 km
# 31      정안IC       풍세교
#     중앙선지선1   중앙선지선2
# 0  대동1(김해)     양산천교
# 1      증산교  대동1(김해)
# 2      남양산      남양산
# 3  대동2(김해)  대동2(김해)
# 4  대동3(김해)      증산교
# 5   양산낙동강교       물금
# 6     양산천교  대동3(김해)
# 7       물금   양산낙동강교
#              대구포항선1           대구포항선2
# 0              도평터널             도평터널
# 1            도동분기점2           도동분기점2
# 2    [포항]달전터널(포항외부)   [포항]달전터널(포항외부)
# 3   [대구]임고1터널(대구외부)      임고4터널(포항#4)
# 4               화산교             도동대교
# 5               서포항              수성리
# 6              도동대교            임고3터널
# 7                포항  [포항]임고4터널(포항외부)
# 8               수성리             벽계천교
# 9   [대구]임고4터널(대구외부)             덕연1교
# 10            임고3터널  [포항]임고1터널(포항외부)
# 11  [포항]임고4터널(포항외부)   [포항]와촌터널(포항외부)
# 12             덕연1교            청통휴게소
# 13   [포항]와촌터널(포항외부)             사동2교
# 14              팔공산  [대구]임고1터널(대구외부)
# 15            청통휴게소              북영천
# 16             사동2교            임고4터널
# 17            임고4터널       와촌터널(포항#6)
# 18             벽계천교            임고2터널
# 19            임고2터널             박사천교
# 20             박사천교             죽곡2교
# 21             죽곡2교             신덕육교
# 22       와촌터널(대구#5)       도동분기점_대구포항
# 23       도동분기점_대구포항              화산교
# 24              와촌교               포항
# 25             백안터널              서포항
# 26         달전터널(외부)              와촌교
# 27             매산육교             백안터널
# 28            와촌휴게소         달전터널(외부)
# 29             신덕육교             매산육교
# 30              북영천            와촌휴게소
# 31  [포항]임고1터널(포항외부)             화남육교
# 32             청통와촌             기계4교
# 33      임고4터널(대구#6)   [대구]와촌터널(대구외부)
# 34             화남육교              보성교
# 35             기계4교             청통와촌
# 36   [대구]와촌터널(대구외부)              현내교
# 37              보성교              팔공산
# 38              현내교              석촌리
# 39              석촌리              NaN
#         구리포천선1      구리포천선2
# 0         신북IC        별내2교
# 1        남구리IC    감암1교(포천)
# 2        이동교1교       남별내IC
# 3        별내휴게소   구리터널관리사무소
# 4        중랑IC교       중랑IC교
# 5        용암천1교       용암천1교
# 6         별내2교        신북TG
# 7         신북TG     유교교(구리)
# 8      유교교(구리)      포천IC북측
# 9     방축1교(구리)        소흘IC
# 10    동의정부IC북측      포천IC남측
# 11        소흘IC    동의정부IC북측
# 12       갈매2육교       갈매2육교
# 13       남별내IC   선단IC교(구리)
# 14        민락IC       남구리IC
# 15   구리터널관리사무소    방축1교(구리)
# 16    감암1교(포천)        소흘JC
# 17        소흘JC  의정부휴게소(구리)
# 18  의정부휴게소(구리)       별내휴게소
# 19      포천IC북측       이동교1교
# 20      포천IC남측        민락IC
# 21   선단IC교(구리)        신북IC
#       중부내륙선1           중부내륙선2
# 0         공평               공평
# 1       삼대2교             점촌함창
# 2    청계_중부내륙             삼대2교
# 3       신화2교              소류지
# 4       태곡육교             신화2교
# ..       ...              ...
# 199      궁1교               괴산
# 200    고령1터널            고령1터널
# 201     문촌3교  [마산]금사3터널(마산외부)
# 202     흑암1교             문촌3교
# 203      NaN             흑암1교
#
# [204 rows x 2 columns]
#      호남선1  호남선2
# 0    대덕육교    구덕
# 1      구덕   송강교
# 2     송강교    산덕
# 3      산덕  용정육교
# 4    용정육교   학구교
# ..    ...   ...
# 128    해전  두월육교
# 129  두월육교    감곡
# 130    감곡    월곡
# 131   행정교   행정교
# 132   경악교   경악교
#
# [133 rows x 2 columns]
#   중앙선(삼락-대동)1 중앙선(삼락-대동)2
# 0         괴정교       대동주차대
# 1       대동주차대          초정
# 2    대동-대감분기점      강서낙동강교
# 3       대동분기점       대동분기점
# 4      강서낙동강교    대동-대감분기점
# 5          초정         괴정교

# %%
print(nm)
# Out:
# ['상곡교', '단밀2터널', '문의교', '파천1터널(청주외부1)', '문동1', '길안3터널(영덕외부2)', '영덕', '지품6터널(영덕외부)', '북의성', '달산2터널(영덕외부)', '동안동', '내서1터널(상주)', '회인쉼터(청주)', '파천3터널(영덕외부1)', '회인', '현하천1교', '지품9터널(청주외부)', '갈평육교', '[청원]문의1터널(청원2)', '미천교', '수리티터널(청주)-외부', '진보터널(청주외부)', '묵계1교', '상주휴게소', '단촌철교', '지품3터널(청주외부)', '수리티교', '지품6터널(청주외부)', '단밀2터널(청주외부)', '영덕터널(청주외부)', '안평1터널(청주외부1)', '영덕터널(청주외부2)', '파천1터널(청주외부2)', '지품2터널(영덕외부)', '안평2터널(영덕외부)', '갈평교', '나각산터널(영덕외부)', '문의휴게소1', '구병산교', '길안3터널(영덕외부1)', '청송', '낙동분기점_청주상주', '화서', '수한터널', '지천4교', '길안4터널(청주외부)', '운평1교', '지품2터널(청주외부)', '길안1터널(청주외부)', '성암교', '파천3터널(영덕외부2)', '서변1교', '문의2터널(청주)-외부', '상주쉼터(상주)', '지품7터널(청주외부)', '서원4교', '지품8터널(청주외부)', '척산1', '평각3교', '안평1터널(청주외부2)', '장림천교', '척산', '지품2교', '탄부터널', '사일산터널(청주외부1)', '지품8터널(영덕외부)', '단촌2터널', '지품7터널(영덕외부)', '안평2터널(영덕외부2)', '상주분기점', '내서3터널(청주)-외부', '삼가천교', '속리산', '단촌4터널(청주외부2)', '화서휴게소', '안사2터널(청주외부)', '양곡교', '지품10터널(영덕외부)', '지사교', '달천1교', '회인터널(상주)-외부', '서원1교', '문동', '[청원]내서1터널(청원)', '파천2터널(청주외부)', '안동분기점', '지품1터널(청주외부)', '평온교', '보은', '내서1교', '옥산터널', '길안1터널', '길안천교', '안평2터널(청주외부)', '서원3교', '사일산터널(영덕외부)', '동상주', '가덕', '단촌1터널', '속리산휴게소', '신촌', '달산2터널(영덕외부1)', '단촌4터널(청주외부1)', '피반령터널(청주)-외부', '의성SA', '단밀4터널(청주외부)', '단밀1터널', '파천3터널(청주외부)', '금굴교', '문의1터널(상주)-외부', '지품3터널(영덕외부)', '상주쉼터(청주)', '탄부', '복곡2교', '서재교', '문의휴게소', '서의성', '성리교', '문의', '지품10터널(청주외부)', '단촌3터널(영덕외부)', '내서1터널', '안사1터널(영덕외부)', '금산리', '동청송영양', '청주분기점', '안평3터널(청주외부)', '점곡SA(영덕)', '남상주', '단밀2터널', '문의교', '파천1터널(청주외부1)', '화서', '상곡교', '문동1', '길안3터널(영덕외부2)', '영덕', '지품6터널(영덕외부)', '달산2터널(영덕외부)', '금굴교', '내서1터널(상주)', '회인쉼터(청주)', '영덕터널(청주외부2)', '파천3터널(영덕외부1)', '현하천1교', '지품9터널(청주외부)', '갈평육교', '상주분기점', '미천교', '양곡교', '묵계1교', '상주휴게소', '사일산터널(청주외부2)', '지품3터널(청주외부)', '회인', '수리티교', '단밀2터널(청주외부)', '영덕터널(청주외부)', '안평1터널(청주외부1)', '동안동', '지품2터널(영덕외부)', '청송', '장림천교', '안평2터널(영덕외부)', '갈평교', '문의휴게소1', '청주분기점', '구병산교', '문의휴게소', '길안3터널(영덕외부1)', '수한터널', '회인터널(상주)-외부', '길안4터널(청주외부)', '운평1교', '지품2터널(청주외부)', '길안1터널(청주외부)', '성암교', '파천3터널(영덕외부2)', '서변1교', '문의', '상주쉼터(상주)', '남상주', '지품7터널(청주외부)', '서원4교', '지품8터널(청주외부)', '척산1', '문의2터널(상주)-외부', '진보터널(청주외부)', '안평1터널(청주외부2)', '척산', '지품2교', '탄부터널', '사일산터널(청주외부1)', '지품8터널(영덕외부)', '단촌2터널', '지품7터널(영덕외부)', '안평2터널(영덕외부2)', '내서3터널(청주)-외부', '삼가천교', '단촌4터널(청주외부2)', '화서휴게소', '안사2터널(청주외부)', '안동분기점', '지품10터널(영덕외부)', '지사교', '달천1교', '서원1교', '문동', '파천2터널(청주외부)', '내서3터널(상주)-외부', '지품1터널(청주외부)', '평온교', '나각산터널(영덕외부)', '내서1교', '동청송영양', '단촌철교', '옥산터널', '길안1터널', '서원3교', '사일산터널(영덕외부)', '가덕', '단촌1터널', '속리산휴게소', '신촌', '달산2터널(영덕외부1)', '지천4교', '평각3교', '단촌4터널(청주외부1)', '피반령터널(청주)-외부', '의성SA', '보은', '단밀4터널(청주외부)', '단밀1터널', '파천3터널(청주외부)', '문의1터널(상주)-외부', '동상주', '낙동분기점_청주상주', '지품3터널(영덕외부)', '상주쉼터(청주)', '탄부', '복곡2교', '서재교', '성리교', '길안천교', '지품10터널(청주외부)', '파천1터널(청주외부2)', '단촌3터널(영덕외부)', '문의1터널(상주2)', '내서1터널', '안사1터널(영덕외부)', '금산리', '북의성', '서의성', '속리산', '안평3터널(청주외부)', '점곡SA(영덕)', '소양천교', '의암교', '마이산 졸음쉼터(익산)', '진안1터널', '오천1교', '[익산]장수터널(익산외부)', '고산천교', '물곡교', '[장수]곰티터널(장수외부)', '화심1교', '[익산]곰티터널(익산외부)', '연장2교', '진안교', '[익산]부귀2터널(익산외부)', '완주휴게소', '노평', '명덕1교', '진안', '[장수]부귀1터널(장수외부)', '익산분기점2', '[익산]상관2터널(익산외부)', '마이산 졸음쉼터(장수)', '진안휴게소', '방곡터널익산외부(고정)', '오천2교', '곰티터널익산#10(고정)', '신탁2교', '완주', '명덕2교', '석전', '완주분기점2', '장수_익산포항', '장수터널익산#3(고정)', '소양', '구룡2교', '단양1교', '[장수]방곡터널(장수외부)', '연장1교', '완주분기점_익산장수', '상관교', '의암교', '익산분기점2', '마이산 졸음쉼터(익산)', '노평', '진안1터널', '진안휴게소', '오천1교', '완주분기점_익산장수', '물곡교', '[장수]곰티터널(장수외부)', '화심1교', '완주분기점2', '[익산]곰티터널(익산외부)', '완주', '[장수]장수터널(장수외부)', '연장2교', '고산천교', '진안교', '장수_익산포항', '소양', '완주휴게소', '명덕1교', '[장수]부귀1터널(장수외부)', '곰티터널장수#3(고정)', '진안', '마이산 졸음쉼터(장수)', '방곡터널익산외부(고정)', '오천2교', '소양천교', '신탁2교', '장수터널장수#7(고정)', '명덕2교', '석전', '구룡2교', '단양1교', '[장수]방곡터널(장수외부)', '연장1교', '상관교', '석문령터널서측', '양주IC', '석문령터널동측', '옥정IC', '석문령터널서측', '양주IC', '옥정IC', '석문령터널동측', '신월천교', '산곡분기점', '가산교', '화산', '중부1터널', '낙타고개1', '진천쉼터(하남)', '일죽쉼터(남이)', '동서울영업소', '남이천', '용면교', '미호천', '오창 졸음쉼터', '하남', '마장분기점_중부', '증평', '후안2교', '일죽', '진천터널2', '경기광주분기점1', '서청주', '백곡천교', '초평교', '청용', '평동육교', '삼호교', '일죽쉼터(하남)', '여천교', '비하', '호법분기점_중부', '광주', '상산곡교',  ...

# %%
import pandas as pd
nm = pd.DataFrame(nm,columns=['cctv'])
nm.to_csv('./cctv.csv')
